# %%
import pandas as pd, json, matplotlib.pyplot as plt
feat = "/workspace/data/processed/2010.SR_features.parquet"
summ = "/workspace/data/processed/2010.SR_backtest_summary.json"
df = pd.read_parquet(feat)
summary = json.load(open(summ))
summary

df.plot(x="Date", y=["eq_curve","bh_curve"], figsize=(10,4), title="Strategy vs Buy&Hold")
plt.show()
